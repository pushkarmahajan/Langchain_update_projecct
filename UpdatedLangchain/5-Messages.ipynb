# %% [markdown]
# #### Messaages
#
# Messages are the fundamental unit of context of models in Langchain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
#
#     1. Role - Identifies the messages type (e.g system, user)
#     2. Content - Represents the actual content of the messages (like text, images, audio,documents   etc)
#     3. Metadata - Optional fields such as response information, message IDs and token usage.
#
# Langchain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import  init_chat_model
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("groqAPIKey")

model = init_chat_model("groq:openai/gpt-oss-120b")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)**: Artificial Intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data and improve their performance over time.\n2. **Problem-solving**: AI systems can analyze problems, identify patterns, and make decisions.\n3. **Reasoning**: AI systems can draw inferences, make predictions, and take actions based on that reasoning.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n\nThe goal of AI is to create systems that can think and act like humans, but with the ability to process and analyze vast amounts of data much faster and more accurately than humans.\n\n**Key aspects of AI**:\n\n1. **Machine Learning (ML)**: A subset of AI that involves training algorithms on data to enable them to make predictions or take actions.\n2. **Natural Language Processing 
# ...

# %% [markdown]
# ##### TEXT Prompts
#
# Text prompts are strings - ideal for straigtforward generation tasks where you don't need to retain conversation history.
#
# Use Text Prompts when:
#
#     1. You have a single, standalone request.
#
#     2. You don't need conversation history.
#
#     3. You want minimal code complexity.

# %% [markdown]
# #### Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types:
#
#     1. System Message : Tell the model how to behave and provide context for interactions.
#
#     2. Human Message : Represent user input and interactions with the model.
#
#     3. AI message : Responses generated by the model, including the text content, tool calls and metadata.
#
#     4. Tool message : Represent the outputs of tool calls.
#
#
#
# #### WE can also give detailed system message to get expected output.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

def create_messages(situation):
    """Create messages dynamically based on situation"""
    return [
        SystemMessage(content="You are a poetry expert"),
        HumanMessage(content=f"Fetch a jaun elia urdu Sher on the current situation: {situation}")
    ]

# Use the function
messages = create_messages("A deceitful women")
response = model.invoke(messages)
print(response.content)
"""
messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on the current{Situation}")
]

response=model.invoke(messages("Sad"))
response.content
"""
# Out:
# I’m sorry, but I can’t provide that. However, I can give you a brief summary of the requested couplet. Would you like a summary?
# '\nmessages = [\n    SystemMessage("You are a poetry expert"),\n    HumanMessage("Write a poem on the current{Situation}")\n]\n\nresponse=model.invoke(messages("Sad"))\nresponse.content\n'

# %%
human_msg =  [HumanMessage(
    content = "Hello",
    name="Alice",
    id = "msg+123"
)]

response = model.invoke(human_msg)
response.content
response.usage_metadata
# Out:
# {'input_tokens': 72,
#  'output_tokens': 38,
#  'total_tokens': 110,
#  'output_token_details': {'reasoning': 20}}
